# %% [markdown]
# # The Numpy Random Package
#
#
#
# [Official Documenation](https://numpy.org/doc/stable/reference/random/index.html)
#
# ***

# %%
# efficent numerical arrays
import numpy as np

# plotting
import matplotlib.pyplot as plt

#change default plot
plt.style.use('fivethirtyeight')

# change default fig size
plt.rcParams['figure.figsize'] = [12, 6]

# %% [markdown]
# <br>
#
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
mu, sigma = 0, 0.1 # mean and standard deviation

s = np.random.normal(mu, sigma, 1000)

# %%
# look at first ten items
s[:10]
# Out:
# array([-0.08120557, -0.05756907,  0.05152634,  0.05396006, -0.16035805,
#        -0.13511104,  0.12834669,  0.16743386,  0.0601238 ,  0.00403786])

# %%
abs(mu - np.mean(s))
0.0  # may vary
# Out:
# 0.0

# %%
abs(sigma - np.std(s, ddof=1))
0.1  # may vary
# Out:
# 0.1

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f=1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-(bins-mu)**2/(2*sigma**2) )
plt.plot(bins, f,linewidth=2)
plt.show()

# %% [markdown]
# ## Rererences
#
# [1] https://realpython.com/python-random/
#
# [2] https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %% [markdown]
# ***
#
# # End
